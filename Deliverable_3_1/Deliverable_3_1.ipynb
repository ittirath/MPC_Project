# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os
import sys

parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
import numpy as np
from LinearMPC.MPCVelControl import MPCVelControl
from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 10 # arbitrary
H = 7 # settling time in seconds = horizon in seconds -> N = H / Ts = 140 steps
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 0, 0, 0, 0, 10])  # initial state: v_x = 5 m/s
# x0 = np.array([0, 0, 0, 0, 0, 0, 0, 5, 0, 0, 0, 10])  # initial state: v_y = 5 m/s
# x0 = np.array([0, 0, 0, 0, 0, 0, 0, 0, 5, 0, 0, 10])  # initial state: v_z = 5 m/s
# x0 = np.array([0, 0, 0, 0, 0, np.deg2rad(40), 0, 0, 0, 0, 0, 10])  # initial state: gamma = 40 deg


rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)



t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, _ = rocket.simulate_control(
    mpc, sim_time, H, x0, method="linear"
) # x_target,u_target = None by default -> tracking zero

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:, :-1], u_cl, T_ol=t_ol[..., :-1], X_ol=x_ol, U_ol=u_ol)
# Out:
# Maximum invariant set successfully computed after 8 iterations.
# MPC X velocity controller created.
# Maximum invariant set successfully computed after 6 iterations.
# MPC Y velocity controller created.
# Maximum invariant set successfully computed after 96 iterations.
# MPC Z velocity controller created.
# Maximum invariant set successfully computed after 52 iterations.
# MPC Roll controller created.
# Simulating time 0.00: Warning: MPC solver failed with status: infeasible
# Input Pavg violation: 0.00 < 40.00,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#      10 rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
#      11 mpc = MPCVelControl().new_controller(rocket, Ts, H)
# ---> 13 t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, _ = rocket.simulate_control(
#      14     mpc, sim_time, H, x0, method="linear"
#      15 ) # x_target,u_target = None by default -> tracking zero
#      17 vis = RocketVis(rocket, rocket_obj_path)
#      18 vis.anim_rate = 1.0
#
# File ~/Documents/model_predictive_control/project/src/rocket.py:427, in Rocket.simulate_control(self, mpc, sim_time, H, x0, method, x_target, u_target, pos_control)
#     425     x_target[6:9, k] = pos_control.get_u(x_cl[9:12, k])
#     426 u_cl[:, k], x_ol[..., k], u_ol[..., k], t_ol[..., k] = mpc.get_u(t_cl[k], x_cl[:, k], x_target=x_target[:, k], u_target=u_target)
# --> 427 x_cl[:, k+1] = current_rocket.simulate_step(x_cl[:, k], self.Ts, u_cl[:, k], method=method)
#     428 mpc.estimate_parameters(x_cl[:, k:k+2], u_cl[:, k:k+1])
#     429 t_cl[k+1] = t_cl[k] + self.Ts
#
# File ~/Documents/model_predictive_control/project/src/rocket.py:378, in Rocket.simulate_step(self, x0, Ts, u0, method)
#     376 def simulate_step(self, x0: np.ndarray, Ts: float, u0: np.ndarray, method: str='nonlinear') -> np.ndarray:
#     377     if constraint_check(self, x0, u0):
# --> 378         raise ValueError("Constraints violation detected, terminating...")
#     380     u0 = self.fuel_dynamics(u0, Ts)
#     381     if method == 'linear':
#
# ValueError: Constraints violation detected, terminating...
